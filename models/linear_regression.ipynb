# %% [markdown]
# ## LINEAR RIGRESSION

# %% [markdown]
# this is linear rigression from scratch

# %%
# Linear Regression from scratch
import numpy as np
import matplotlib.pyplot as plt

# Handmade data
x = np.array([1,2,3,4,5,6,7,8])
y = np.array([2,4,5,4,5,7,8,9])

n = len(x)

# Calculating slope (m) and intercept (c)
m = (n*np.sum(x*y) - np.sum(x)*np.sum(y)) / (n*np.sum(x**2) - (np.sum(x))**2)
c = (np.sum(y) - m*np.sum(x)) / n

print(f"Slope (m): {m}")
print(f"Intercept (c): {c}")

# Prediction
y_pred = m*x + c

# Plot
plt.scatter(x, y, color="red", label="Original Data")
plt.plot(x, y_pred, color="blue", label="Best Fit Line")
plt.xlabel("Hours studied")
plt.ylabel("Exam Score")
plt.legend()
plt.show()
# Out:
# Slope (m): 0.9047619047619048
# Intercept (c): 1.4285714285714288
